# %% [markdown]
# <a href="https://colab.research.google.com/github/kiemtradiemthithptqg/Colab-Cloud-Gaming/blob/main/ColabSteam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Tap this if you play on Mobile { display-mode: "form" }
# %%html
<b>Ensure this audio is playing to prevent colab from shutting down, then start ColabSteam below</b><br/>
<audio autoplay="" src="https://github.com/kmille36/Colab-Cloud-Gaming/raw/refs/heads/main/silence.m4a" loop controls>
# Out:
# <b>Ensure this audio is playing to prevent colab from shutting down, then start ColabSteam below</b><br/>
# <audio autoplay="" src="https://github.com/kmille36/Colab-Cloud-Gaming/raw/refs/heads/main/silence.m4a" loop controls>

# %%
#@title 🌐 Colab Region Check  { display-mode: "form" }

import subprocess
import time
from google.colab import runtime

# Get region
region = subprocess.check_output(
    "curl -s ipinfo.io | grep region | cut -d\\\" -f4",
    shell=True
).decode().strip()

print(f"Your current region: {region}")

try:
    print("Automatically keeping this runtime in 15 seconds... (Press Ctrl+C to unassign)")
    for i in range(15, 0, -1):
        print(f"{i}...", end="", flush=True)
        time.sleep(1)
    print("\nKeeping current runtime...")

except KeyboardInterrupt:
    print("\nCtrl+C detected — unassigning runtime...")
    runtime.unassign()
# Out:
# Your current region: Singapore
# Automatically keeping this runtime in 15 seconds... (Press Ctrl+C to unassign)
# 15...14...13...12...11...10...9...
# Ctrl+C detected — unassigning runtime...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-168917220.py in <cell line: 0>()
#      18         print(f"{i}...", end="", flush=True)
# ---> 19         time.sleep(1)
#      20     print("\nKeeping current runtime...")
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-168917220.py in <cell line: 0>()
#      22 except KeyboardInterrupt:
#      23     print("\nCtrl+C detected — unassigning runtime...")
# ---> 24     runtime.unassign()
#
# /usr/local/lib/python3.12/dist-packages/google/colab/runtime.py in unassign()
#      33         'Unable to find the runtime management service.'
#      34     )
# ---> 35   resp, _ = h.request(f'http://{runtime_server_addr}/unassign', 'POST')
#      36   if resp.status != _http.HTTPStatus.OK:
#      37     raise _errors.RuntimeManagementError('Unable to request VM unassignment.')
#
# /usr/local/lib/python3.12/dist-packages/httplib2/__init__.py in request(self, uri, method, body, headers, redirections, connection_type)
#    1725                     content = b""
#    1726                 else:
# -> 1727                     (response, content) = self._request(
#    1728                         conn, authority, uri, request_uri, method, body, headers, redirections, cachekey,
#    1729                     )
#
# /usr/local/lib/python3.12/dist-packages/httplib2/__init__.py in _request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1445             auth.request(method, request_uri, headers, body)
#    1446
# -> 1447         (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#    1448
#    1449         if auth:
#
# /usr/local/lib/python3.12/dist-packages/httplib2/__init__.py in _conn_request(self, conn, request_uri, method, body, headers)
#    1397                 pass
#    1398             try:
# -> 1399                 response = conn.getresponse()
#    1400             except (http.client.BadStatusLine, http.client.ResponseNotReady):
#    1401                 # If we get a BadStatusLine on the first try then that means
#
# /usr/lib/python3.12/http/client.py in getresponse(self)
#    1428         try:
#    1429             try:
# -> 1430                 response.begin()
#    1431             except ConnectionError:
#    1432                 self.close()
#
# /usr/lib/python3.12/http/client.py in begin(self)
#     329         # read until we get a non-100 response
#     330         while True:
# --> 331             version, status, reason = self._read_status()
#     332             if status != CONTINUE:
#     333                 break
#
# /usr/lib/python3.12/http/client.py in _read_status(self)
#     290
#     291     def _read_status(self):
# --> 292         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293         if len(line) > _MAXLINE:
#     294             raise LineTooLong("status line")
#
# /usr/lib/python3.12/socket.py in readinto(self, b)
#     718         while True:
#     719             try:
# --> 720                 return self._sock.recv_into(b)
#     721             except timeout:
#     722                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#@title 🖥️ Colab Cloud Game Mode by NT.Hai { display-mode: "form" }
Mount_Google_Drive = False #@param {type:"boolean"}

if Mount_Google_Drive:
    from google.colab import drive
    drive.mount('/content/drive')
    print("✅ Drive mounted.")
else:
    print("⛔ Skipped mount.")

# !wget -q https://github.com/kmille36/Colab-Cloud-Gaming/raw/refs/heads/main/ColabSteam && chmod +x ColabSteam && ./ColabSteam
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-3192535923.py in <cell line: 0>()
#       4 if Mount_Google_Drive:
#       5     from google.colab import drive
# ----> 6     drive.mount('/content/drive')
#       7     print("✅ Drive mounted.")
#       8 else:
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful
